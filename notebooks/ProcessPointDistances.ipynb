# %% [markdown]
# ## Process Probed Point Distances
#
# In this notebook we ingest, examine, and join data for evaluation of SmartSPIM to CCF registration.
#
# ## Inputs
#
# 1. List of surface distances between registered and baseline label annotation surfaces
# 2. Dice overlap agreement results comparing registered and baseline label image surfaces
#
# ## See Also
#
# Batch processing CLI: `../src/aind-ccf-alignment-experiments/postprocess_cli.py`

# %%
INPUT_DISTANCES_PATH = r"D:\repos\allen-registration\notebooks\data\results\652506\LEVEL_3\2023.06.05\Ex_561_Em_593\labels\split"

# %%
import glob
import os
import re
import sys

import numpy as np
import pandas as pd
import itk

itk.auto_progress(1)

import sys

sys.path.append("../src")
from aind_ccf_alignment_experiments.url import parse_sample_filepath

# %%
(
    subject_id,
    channel_id,
    registration_date,
    experiment_name,
) = parse_sample_filepath(INPUT_DISTANCES_PATH)
print(
    f"Parsing results for subject {subject_id}, experiment {experiment_name}, channel {channel_id}"
)
# Out:
# Parsing results for subject 652506, experiment LEVEL_3, channel Ex_561_Em_593

# %% [markdown]
# ## Load and Examine Distances

# %%
distance_filepaths = glob.glob(
    f"{INPUT_DISTANCES_PATH}/*{channel_id}_labels_*_distances.csv"
)
print(f"Found {len(distance_filepaths)} files with point boundary distances")

assert len(distance_filepaths) > 0
# Out:
# Found 4 files with point boundary distances

# %%
distances = {}

for distance_filepath in distance_filepaths:
    label_value = int(
        re.match(".*_labels_([0-9]*)_distances.csv", distance_filepath).group(
            1
        )
    )
    distances[label_value] = np.loadtxt(distance_filepath)
    print(
        f"{len(distances[label_value])} point distances for label {label_value}"
    )
# Out:
# 42609 point distances for label 473
# 17342 point distances for label 585
# 19814 point distances for label 788
# 35861 point distances for label 890

# %%
# Create dummy entry for overview of all label results
combined_distances = np.array([])

for label_value in distances:
    combined_distances = np.concatenate(
        (combined_distances, distances[label_value]), axis=0
    )

distances[-1] = combined_distances
print(f"{distances[-1].shape[0]} point distances for label -1 (all)")
# Out:
# 115626 point distances for label -1 (all)

# %%
def make_distance_entry(
    subject_id,
    channel_name,
    experiment_id,
    registration_date,
    label_value,
    headers,
    distances,
) -> pd.DataFrame:
    return pd.DataFrame(
        [
            [
                subject_id,
                channel_name,
                experiment_id,
                registration_date,
                label_value,
                len(distances),
                np.mean(distances),
                np.std(distances),
                np.min(distances),
                np.median(distances),
                np.max(distances),
            ]
        ],
        columns=headers,
    )

# %%
# Signed distances
distance_headers = [
    "subject_id",
    "channel_id",
    "experiment_id",
    "registration_date",
    "label_value",
    "count",
    "mean",
    "std",
    "min",
    "median",
    "max",
]
signed_distance_descriptors = pd.DataFrame([], columns=distance_headers)

for label_value in distances:
    signed_distance_descriptors = pd.concat(
        [
            signed_distance_descriptors,
            make_distance_entry(
                subject_id,
                channel_id,
                experiment_name,
                registration_date,
                label_value,
                distance_headers,
                distances[label_value],
            ),
        ],
        ignore_index=True,
    )

signed_distance_descriptors.head()
# Out:
#   subject_id     channel_id experiment_id registration_date label_value  \
# 0     652506  Ex_561_Em_593       LEVEL_3        2023.06.05         473
# 1     652506  Ex_561_Em_593       LEVEL_3        2023.06.05         585
# 2     652506  Ex_561_Em_593       LEVEL_3        2023.06.05         788
# 3     652506  Ex_561_Em_593       LEVEL_3        2023.06.05         890
# 4     652506  Ex_561_Em_593       LEVEL_3        2023.06.05          -1
#
#     count      mean       std       min        median       max
# 0   42609  0.000575  0.040988 -0.143190  8.483461e-44  0.149448
# 1   17342  0.020314  0.060305 -0.096413  2.267090e-02  0.142637
# 2   19814  0.057695  0.052597 -0.067114  6.510509e-02  0.193371
# 3   35861 -0.002529  0.051377 -0.127839  1.469402e-43  0.109212
# 4  115626  0.012361  0.054212 -0.143190  9.264400e-03  0.193371

# %%
abs_distance_headers = [
    "subject_id",
    "channel_id",
    "experiment_id",
    "registration_date",
    "label_value",
    "count",
    "abs_mean",
    "abs_std",
    "abs_min",
    "abs_median",
    "abs_max",
]
abs_distance_descriptors = pd.DataFrame([], columns=abs_distance_headers)

for label_value in distances:
    abs_distances = np.abs(distances[label_value])
    abs_distance_descriptors = pd.concat(
        [
            abs_distance_descriptors,
            make_distance_entry(
                subject_id,
                channel_id,
                experiment_name,
                registration_date,
                label_value,
                abs_distance_headers,
                abs_distances,
            ),
        ],
        ignore_index=True,
    )

abs_distance_descriptors.head()
# Out:
#   subject_id     channel_id experiment_id registration_date label_value  \
# 0     652506  Ex_561_Em_593       LEVEL_3        2023.06.05         473
# 1     652506  Ex_561_Em_593       LEVEL_3        2023.06.05         585
# 2     652506  Ex_561_Em_593       LEVEL_3        2023.06.05         788
# 3     652506  Ex_561_Em_593       LEVEL_3        2023.06.05         890
# 4     652506  Ex_561_Em_593       LEVEL_3        2023.06.05          -1
#
#     count  abs_mean   abs_std       abs_min  abs_median   abs_max
# 0   42609  0.030192  0.027727  4.897538e-44    0.022760  0.149448
# 1   17342  0.054229  0.033296  4.897538e-44    0.053708  0.142637
# 2   19814  0.065939  0.041800  4.897538e-44    0.066069  0.193371
# 3   35861  0.043761  0.027037  4.897538e-44    0.043398  0.127839
# 4  115626  0.044131  0.033825  4.897538e-44    0.037158  0.193371

# %%
distance_descriptors = pd.merge(
    signed_distance_descriptors,
    abs_distance_descriptors,
    on=[
        "subject_id",
        "channel_id",
        "experiment_id",
        "registration_date",
        "label_value",
        "count",
    ],
)
distance_descriptors.head()
# Out:
#   subject_id     channel_id experiment_id registration_date label_value  \
# 0     652506  Ex_561_Em_593       LEVEL_3        2023.06.05         473
# 1     652506  Ex_561_Em_593       LEVEL_3        2023.06.05         585
# 2     652506  Ex_561_Em_593       LEVEL_3        2023.06.05         788
# 3     652506  Ex_561_Em_593       LEVEL_3        2023.06.05         890
# 4     652506  Ex_561_Em_593       LEVEL_3        2023.06.05          -1
#
#     count      mean       std       min        median       max  abs_mean  \
# 0   42609  0.000575  0.040988 -0.143190  8.483461e-44  0.149448  0.030192
# 1   17342  0.020314  0.060305 -0.096413  2.267090e-02  0.142637  0.054229
# 2   19814  0.057695  0.052597 -0.067114  6.510509e-02  0.193371  0.065939
# 3   35861 -0.002529  0.051377 -0.127839  1.469402e-43  0.109212  0.043761
# 4  115626  0.012361  0.054212 -0.143190  9.264400e-03  0.193371  0.044131
#
#     abs_std       abs_min  abs_median   abs_max
# 0  0.027727  4.897538e-44    0.022760  0.149448
# 1  0.033296  4.897538e-44    0.053708  0.142637
# 2  0.041800  4.897538e-44    0.066069  0.193371
# 3  0.027037  4.897538e-44    0.043398  0.127839
# 4  0.033825  4.897538e-44    0.037158  0.193371

# %% [markdown]
# ## Load and Compare With Dice

# %%
dice_overlap_filepath = glob.glob(
    f"{os.path.dirname(INPUT_DISTANCES_PATH)}/*_{channel_id}_overlap.csv"
)[0]
dice_overlap_results = pd.read_csv(dice_overlap_filepath)

if "Unnamed: 0" in dice_overlap_results.keys():
    del dice_overlap_results["Unnamed: 0"]

print(
    f"Loaded {dice_overlap_results.shape} results from {dice_overlap_filepath}"
)
dice_overlap_results.head()
# Out:
# Loaded (5, 3) results from D:\repos\allen-registration\notebooks\data\results\652506\LEVEL_3\2023.06.05\Ex_561_Em_593\labels\652506_Ex_561_Em_593_overlap.csv
#   ccf_label_name  ccf_label_value  dice_score
# 0            all               -1    0.263239
# 1           VIIn              788    0.188000
# 2             MH              473    0.678777
# 3             fr              585    0.228743
# 4            aco              890    0.134285

# %%
distances_and_overlap = pd.merge(
    distance_descriptors,
    dice_overlap_results,
    left_on=["label_value"],
    right_on=["ccf_label_value"],
)
distances_and_overlap.head()
# Out:
#   subject_id     channel_id experiment_id registration_date label_value  \
# 0     652506  Ex_561_Em_593       LEVEL_3        2023.06.05         473
# 1     652506  Ex_561_Em_593       LEVEL_3        2023.06.05         585
# 2     652506  Ex_561_Em_593       LEVEL_3        2023.06.05         788
# 3     652506  Ex_561_Em_593       LEVEL_3        2023.06.05         890
# 4     652506  Ex_561_Em_593       LEVEL_3        2023.06.05          -1
#
#     count      mean       std       min        median       max  abs_mean  \
# 0   42609  0.000575  0.040988 -0.143190  8.483461e-44  0.149448  0.030192
# 1   17342  0.020314  0.060305 -0.096413  2.267090e-02  0.142637  0.054229
# 2   19814  0.057695  0.052597 -0.067114  6.510509e-02  0.193371  0.065939
# 3   35861 -0.002529  0.051377 -0.127839  1.469402e-43  0.109212  0.043761
# 4  115626  0.012361  0.054212 -0.143190  9.264400e-03  0.193371  0.044131
#
#     abs_std       abs_min  abs_median   abs_max ccf_label_name  \
# 0  0.027727  4.897538e-44    0.022760  0.149448             MH
# 1  0.033296  4.897538e-44    0.053708  0.142637             fr
# 2  0.041800  4.897538e-44    0.066069  0.193371           VIIn
# 3  0.027037  4.897538e-44    0.043398  0.127839            aco
# 4  0.033825  4.897538e-44    0.037158  0.193371            all
#
#    ccf_label_value  dice_score
# 0              473    0.678777
# 1              585    0.228743
# 2              788    0.188000
# 3              890    0.134285
# 4               -1    0.263239

# %% [markdown]
# ## Save and Combine Experiment Results

# %%
sample_results_filepath = (
    rf"{INPUT_DISTANCES_PATH}\distances_versus_overlap.csv"
)
distances_and_overlap.to_csv(sample_results_filepath)
print(f"Saved results to {sample_results_filepath}")
# Out:
# Saved results to D:\repos\allen-registration\notebooks\data\results\652506\LEVEL_3\2023.06.05\Ex_561_Em_593\labels\split\distances_versus_overlap.csv

# %%
COMBINED_RESULTS_FILEPATH = r"D:\repos\allen-registration\notebooks\data\results\652506\compare\distances_versus_overlap.csv"
combined_results = pd.read_csv(COMBINED_RESULTS_FILEPATH)

if "Unnamed: 0" in combined_results.columns:
    del combined_results["Unnamed: 0"]

combined_results.head()
# Out:
#    subject_id     channel_id experiment_id registration_date  label_value  \
# 0      652506  Ex_445_Em_469       ANTS_L4        2023.06.04          473
# 1      652506  Ex_445_Em_469       ANTS_L4        2023.06.04          585
# 2      652506  Ex_445_Em_469       ANTS_L4        2023.06.04          788
# 3      652506  Ex_445_Em_469       ANTS_L4        2023.06.04          890
# 4      652506  Ex_445_Em_469       ANTS_L4        2023.06.04           -1
#
#     count      mean       std       min        median       max  abs_mean  \
# 0   43406  0.000528  0.044648 -0.099591 -9.335111e-03  0.159931  0.037191
# 1   16732  0.006558  0.053620 -0.089793 -9.322135e-03  0.149957  0.043102
# 2   19309  0.085237  0.062440 -0.066421  8.752170e-02  0.259457  0.088785
# 3   33700  0.009891  0.065179 -0.129312  1.314278e-43  0.194552  0.053899
# 4  452588  0.018664  0.063621 -0.129312  9.264400e-03  0.259457  0.051846
#
#     abs_std       abs_min  abs_median   abs_max ccf_label_name  \
# 0  0.024711  4.897538e-44    0.035195  0.159931             MH
# 1  0.032562  4.897538e-44    0.037139  0.149957             fr
# 2  0.057284  4.897538e-44    0.087522  0.259457           VIIn
# 3  0.037961  8.483461e-44    0.050464  0.194552            aco
# 4  0.041328  4.897538e-44    0.043398  0.259457            all
#
#    ccf_label_value  dice_score
# 0              473    0.664242
# 1              585    0.321656
# 2              788    0.084610
# 3              890    0.109716
# 4               -1    0.248681

# %%
combined_results = pd.concat(
    [
        combined_results,
        distances_and_overlap,
    ]
).drop_duplicates(
    [
        "subject_id",
        "channel_id",
        "experiment_id",
        "registration_date",
        "label_value",
    ]
)
combined_results
# Out:
#    subject_id     channel_id experiment_id registration_date label_value  \
# 0      652506  Ex_445_Em_469       ANTS_L4        2023.06.04         473
# 1      652506  Ex_445_Em_469       ANTS_L4        2023.06.04         585
# 2      652506  Ex_445_Em_469       ANTS_L4        2023.06.04         788
# 3      652506  Ex_445_Em_469       ANTS_L4        2023.06.04         890
# 4      652506  Ex_445_Em_469       ANTS_L4        2023.06.04          -1
# 5      652506  Ex_488_Em_525       ANTS_L4        2023.06.04         473
# 6      652506  Ex_488_Em_525       ANTS_L4        2023.06.04         585
# 7      652506  Ex_488_Em_525       ANTS_L4        2023.06.04         788
# 8      652506  Ex_488_Em_525       ANTS_L4        2023.06.04         890
# 9      652506  Ex_488_Em_525       ANTS_L4        2023.06.04          -1
# 10     652506  Ex_561_Em_593       ANTS_L4        2023.06.04         473
# 11     652506  Ex_561_Em_593       ANTS_L4        2023.06.04         585
# 12     652506  Ex_561_Em_593       ANTS_L4        2023.06.04         788
# 13     652506  Ex_561_Em_593       ANTS_L4        2023.06.04         890
# 14     652506  Ex_561_Em_593       ANTS_L4        2023.06.04          -1
# 15     652506  Ex_445_Em_469       LEVEL_4        2023.06.01         473
# 16     652506  Ex_445_Em_469       LEVEL_4        2023.06.01         585
# 17     652506  Ex_445_Em_469       LEVEL_4        2023.06.01         788
# 18     652506  Ex_445_Em_469       LEVEL_4        2023.06.01         890
# 19     652506  Ex_445_Em_469       LEVEL_4        2023.06.01          -1
# 20     652506  Ex_488_Em_525       LEVEL_4        2023.06.01         473
# 31  0.065307  5.901910e-02    0.199019  0.330918             fr
# 32  0.063994  8.970340e-02    0.241350  0.382617           VIIn
# 33  0.106993  1.648153e-01    0.374718  0.593651            aco
# 34  0.135740  0.000000e+00    0.253067  0.593651            all
# 35  0.024951  4.897538e-44    0.029991  0.138067             MH
# 36  0.018672  4.897538e-44    0.025931  0.092744             fr
# 37  0.044578  5.998959e-44    0.069247  0.189484           VIIn
# 38  0.034780  5.998959e-44    0.059019  0.156515            aco
# 39  0.035817  4.897538e-44    0.040219  0.189484            all
# 40  0.026510  4.897538e-44    0.036159  0.139055             MH
# 41  0.029871  4.897538e-44    0.053626  0.122180             fr
# 42  0.040645  4.897538e-44    0.063219  0.182856           VIIn
# 43  0.027917  4.897538e-44    0.049755  0.127839            aco
# 44  0.031486  4.897538e-44    0.046417  0.182856            all
# 45  0.142180  4.897538e-44    0.170159  0.589866             MH
# 46  0.073210  8.265369e-02    0.231021  0.399152             fr
# 47  0.062723  2.999140e-02    0.177479  0.328872           VIIn
# 48  0.135709  1.876910e-01    0.478808  0.776691            aco
# 49  0.179756  4.897538e-44    0.254724  0.776691            all
# 50  0.025195  4.897538e-44    0.025931  0.138067             MH
# 51  0.021251  4.897538e-44    0.033170  0.092247             fr
# 52  0.042183  4.897538e-44    0.068993  0.184378           VIIn
# 53  0.032528  4.897538e-44    0.046658  0.146287            aco
# 54  0.033643  4.897538e-44    0.037058  0.184378            all
# 0   0.027727  4.897538e-44    0.022760  0.149448             MH
# 1   0.033296  4.897538e-44    0.053708  0.142637             fr
# 2   0.041800  4.897538e-44    0.066069  0.193371           VIIn
# 3   0.027037  4.897538e-44    0.043398  0.127839            aco
# 4   0.033825  4.897538e-44    0.037158  0.193371            all
#
#     ccf_label_value  dice_score
# 0               473    0.664242
# 1               585    0.321656
# 2               788    0.084610
# 3               890    0.109716
# 4                -1    0.248681
# 5               473    0.671484
# 6               585    0.389515
# 7               788    0.007537
# 8               890    0.111434
# 9                -1    0.261528
# 10              473    0.565645
# 11              585    0.368210
# 12              788    0.060679
# 13              890    0.223103
# 14               -1    0.308331
# 15              473    0.027698
# 16              585    0.000000
# 17              788    0.000000
# 18              890    0.000000
# 19               -1    0.005926
# 20              473    0.691117
# 21              585    0.472643
# 22              788    0.219311
# 23              890    0.103598
# 24               -1    0.265520
# 25              473    0.620521
# 26              585    0.289844
# 27              788    0.255246
# 28              890    0.111375
# 29               -1    0.243740
# 30              473    0.034124
# 31              585    0.000000
# 32              788    0.000000
# 33              890    0.000000
# 34               -1    0.007291
# 35              473    0.643535
# 36              585    0.437329
# 37              788    0.169556
# 38              890    0.101363
# 39               -1    0.248282
# 40              473    0.611948
# 41              585    0.281116
# 42              788    0.217811
# 43              890    0.128983
# 44               -1    0.250493
# 45              473    0.067551
# 46              585    0.000000
# 47              788    0.000000
# 48              890    0.000000
# 49               -1    0.014673
# 50              473    0.662305
# 51              585    0.405818
# 52              788    0.176415
# 53              890    0.113941
# 54               -1    0.258201
# 0               473    0.678777
# 1               585    0.228743
# 2               788    0.188000
# 3               890    0.134285
# 4                -1    0.263239

# %%
combined_results.to_csv(COMBINED_RESULTS_FILEPATH)
